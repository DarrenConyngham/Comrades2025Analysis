# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd # Recommended for easier data handling after scraping
from time import sleep

# %%
# url = "https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=1"

# %%
def extract_table_data(table):
    # 2. Extract table headers from the first <tr>
    # The provided HTML indicates headers are in <td> tags within the first <tr>,
    # which has specific styling for headers.
    headers = []
    # Find the first <tr> in the table
    first_row = table.find('tr')

    if not first_row:
        print("Error: No rows found in the table, cannot extract headers.")
        return None

    # Extract text from all <td> tags in the first row for headers
    # We need to be careful about duplicate columns due to responsive design classes
    # 'd-none d-sm-table-cell' for desktop/larger screens
    # 'd-sm-none d-xs-table-cell' for mobile/smaller screens
    # Let's prioritize the desktop view headers if both exist, and filter out empty ones.
    potential_headers = first_row.find_all('td')
    
    # Manually define logic for header extraction based on content or specific attributes
    # We will iterate through all <td>s in the first row,
    # but try to extract meaningful text from their direct children (e.g., <a> tags).
    # We also need to manage duplicates like "Name" appearing twice.

    # Heuristic: If a <td> contains an <a> tag, use the text of the <a>.
    # Otherwise, use the direct text of the <td>.
    # We'll collect all potential headers and then clean them.
    for td in potential_headers:
        # Check for a specific structure (like <a> tag with text) for headers
        link = td.find('a', class_='ltw-nodecor')
        if link:
            header_text = link.get_text(strip=True)
        else:
            # For headers without <a>, like 'Fav', 'Share', 'Cat Pos', 'Gen Pos', 'Country'
            # get direct text, stripping whitespace and potentially extra content.
            header_text = td.get_text(strip=True)

        # Filter out social share icons that might mistakenly be picked up as headers
        # These are typically in 'd-none d-sm-table-cell' but are content, not headers.
        # We can also check if text is empty or contains non-alphabetic characters (like sort icons)
        if header_text and not (
            'fa-star' in str(td) or # for 'Fav' column icon in header td
            'x-twitter.svg' in str(td) or # for 'Share' column icons in header td
            'facebook.svg' in str(td) or
            'print.svg' in str(td) or
            'youtube.svg' in str(td)
        ):
            headers.append(header_text)
    
    # Remove potential duplicate "Name" header if both desktop and mobile versions are present
    # The mobile 'Name' header has d-sm-none d-xs-table-cell class
    # The desktop 'Name' header has d-none d-sm-table-cell class
    # Let's ensure we only take the one with 'width:100%' for the main Name column
    cleaned_headers = []
    seen_names = False
    for i, header in enumerate(headers):
        # Check the original td's class to determine which 'Name' it is
        original_td = potential_headers[i] # This mapping might be tricky due to filtering above
        
        # A more reliable way: define the expected headers manually, then map data.
        # However, for automated extraction, we try to parse them.

        # Simplified approach: if we see "Name" twice, keep the first one
        if header == 'Name':
            if not seen_names:
                cleaned_headers.append(header)
                seen_names = True
        elif header == '': # Skip empty headers which might come from image columns
            continue
        else:
            cleaned_headers.append(header)
    
    # Manual inspection of the provided HTML structure reveals the actual headers
    # are: Fav, Pos, Share, Race No, Wave, (Flag), Name, Time, Net Time, Category, Cat Pos, Gender, Gen Pos, Club, Country
    # The empty <td> in the headers is likely for the flag column.
    # Let's refine header extraction to be more robust for the given HTML structure:
    # The first <tr> has 16 <td> elements. We need to map them to meaningful headers.

    # Based on the HTML provided, the headers should be:
    # Fav, Pos, Share, Race No, Wave, (empty for flag), Name (desktop), Name (mobile), Time, Net Time, Category, Cat Pos, Gender, Gen Pos, Club, Country
    # We need to pick one 'Name' and identify the empty one for the flag.

    # Let's rebuild header extraction knowing the structure.
    headers = []
    for td in first_row.find_all('td'):
        # Text from <a> tag within <td> is usually the header, or direct text from <td>
        link = td.find('a', class_='ltw-nodecor')
        if link:
            headers.append(link.get_text(strip=True))
        else:
            # Handle cases like 'Fav', 'Share', 'Cat Pos', 'Gen Pos', 'Country' where text is direct
            # or where it's an image cell without text in the header.
            text = td.get_text(strip=True)
            if 'fa-star' in str(td) and 'Fav' not in headers: # Specifically for the 'Fav' header
                    headers.append('Fav')
            elif 'Share on X' in str(td) and 'Share' not in headers: # Specifically for the 'Share' header
                headers.append('Share')
            elif text: # If there's direct text, use it
                headers.append(text)
            else: # For the empty flag header or other complex hidden ones
                headers.append('') # Placeholder, will be cleaned

    # Post-process headers to fix duplicates and empty ones from responsive design
    final_headers = []
    seen_name = False
    for i, h in enumerate(headers):
        if h == 'Name':
            if not seen_name:
                final_headers.append('Name')
                seen_name = True
            # Skip the second 'Name' which is the mobile version
        elif h == '':
            # This could be the flag column. We'll name it 'Flag' or skip it if it's not a real column
            # Given the data structure, it's the 6th header (index 5)
            if i == 5: # The empty <td> that precedes the main 'Name' column usually for a flag
                final_headers.append('Flag')
            elif 'd-sm-none' in potential_headers[i].get('class', []): # This is likely the mobile pos column that duplicates desktop pos
                continue
            else:
                final_headers.append(h) # Keep other empty ones, might be visual spacers. We'll clean them later.
        elif h == 'Pos' and len(final_headers) > 0 and final_headers[-1] == 'Pos':
            # Skip duplicate 'Pos' from responsive design if it's already added
            continue
        else:
            final_headers.append(h)
    
    # Remove empty strings from headers and ensure uniqueness if necessary (though the HTML implies distinct columns)
    final_headers = [h for h in final_headers if h] # Filter out empty strings
    
    # If headers are still not as expected, manually force them or ensure unique names
    # Based on visual inspection of the table structure, a good set of headers would be:
    # ['Fav', 'Pos', 'Share', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
    # The 'Share' column is actually an action column (social share icons), not a data point itself
    # The 'Fav' is also an action column
    # Let's adjust the `headers` list to reflect meaningful columns for the DataFrame
    
    # A more robust approach for headers:
    # Iterate through the first row's <td> elements, identify the intended column name
    # based on context (text or child <a> text)
    actual_headers = []
    # List of classes that indicate a desktop/larger screen cell to prioritize
    desktop_visible_classes = ['d-none', 'd-sm-table-cell']
    
    # Map original header positions to desired names based on your HTML
    # This is more robust than trying to parse dynamically for this complex header row.
    # This is a bit of a manual mapping given the mixed content and responsive classes.
    # I'll rely on the text of the `<a>` tag or the direct `<td>` text for now.
    
    # Let's try to infer headers based on the text within <a> tags and direct <td> text.
    # Some columns don't have sortable links.
    inferred_headers = []
    for i, td in enumerate(first_row.find_all('td')):
        link_text = ''
        if td.find('a', class_='ltw-nodecor'):
            link_text = td.find('a', class_='ltw-nodecor').get_text(strip=True)
        
        # Special handling for ambiguous/empty headers
        if i == 0: # Fav column
            inferred_headers.append('Fav_Action') # It's an action, not a data column
        elif i == 1: # Pos (Desktop)
            inferred_headers.append('Pos')
        elif i == 2: # Pos (Mobile) - skip this as it's a duplicate of Pos
            continue
        elif i == 3: # Share action column
            inferred_headers.append('Share_Action') # It's an action
        elif i == 4: # Race No
            inferred_headers.append('Race No')
        elif i == 5: # Wave
            inferred_headers.append('Wave')
        elif i == 6: # Flag Image
            inferred_headers.append('Flag')
        elif i == 7: # Name (Desktop)
            inferred_headers.append('Name')
        elif i == 8: # Name (Mobile) - this cell contains Name and Race No, Category for mobile
            # We've already captured 'Name' and 'Race No' from desktop.
            # If we need the combined 'Name #RaceNo Category' for mobile, it's a separate parsing task.
            # For a clean DataFrame, let's skip this as it duplicates 'Name' and 'Race No'.
            continue
        elif i == 9: # Time
            inferred_headers.append('Time')
        elif i == 10: # Net Time
            inferred_headers.append('Net Time')
        elif i == 11: # Category
            inferred_headers.append('Category')
        elif i == 12: # Cat Pos
            inferred_headers.append('Cat Pos')
        elif i == 13: # Gender
            inferred_headers.append('Gender')
        elif i == 14: # Gen Pos
            inferred_headers.append('Gen Pos')
        elif i == 15: # Club
            inferred_headers.append('Club')
        elif i == 16: # Country
            inferred_headers.append('Country')
        else:
            inferred_headers.append(link_text if link_text else td.get_text(strip=True))

    headers = [h for h in inferred_headers if h and h != 'i'] # Filter out empty and stray 'i' from font-awesome

    # Final check on headers, ensure consistency and no redundant columns
    # Based on your HTML, the most useful headers are:
    # Pos, Race No, Wave, Flag, Name, Time, Net Time, Category, Cat Pos, Gender, Gen Pos, Club, Country
    # The "Fav" and "Share" columns are action buttons, so we might want to skip them or
    # represent them as boolean/link columns if needed. For a clean data table,
    # often these action columns are excluded.
    # Let's adjust to extract data relevant to runner details.

    # Let's identify the actual data columns by their position or content.
    # The key is to map the data cells to the correct header.

    # Given the HTML structure, the header row contains TDs.
    # We need to map the data from the subsequent TDs to the correct header names.
    # Let's simplify the header extraction to focus on the text, and then manually
    # filter out columns we don't want (like the action buttons or duplicate mobile columns).

    # Re-attempting header extraction focusing on text content and filtering:
    headers_raw = [td.get_text(strip=True) for td in first_row.find_all('td')]
    
    # The header texts with their indices in the provided HTML:
    # 0: 'Fav' (from font awesome icon, but its <td> text is empty) - skip
    # 1: 'Pos' (desktop)
    # 2: 'Pos' (mobile) - skip
    # 3: '' (Share action column) - skip
    # 4: 'Race No'
    # 5: 'Wave'
    # 6: '' (Flag icon column) - use 'Flag'
    # 7: 'Name' (desktop)
    # 8: 'Name' (mobile, combined) - skip
    # 9: 'Time'
    # 10: 'Net Time'
    # 11: 'Category'
    # 12: 'Cat Pos'
    # 13: 'Gender'
    # 14: 'Gen Pos'
    # 15: 'Club'
    # 16: 'Country'
    
    # Define the target headers and their corresponding column indices in the HTML
    # This is the most reliable way given the complex HTML structure.
    header_map = {
        1: 'Pos',           # Pos (desktop)
        4: 'Race No',
        5: 'Wave',
        6: 'Flag',          # This column has an img, not text, so we'll treat it specially
        7: 'Name',          # Name (desktop)
        9: 'Time',
        10: 'Net Time',
        11: 'Category',
        12: 'Cat Pos',
        13: 'Gender',
        14: 'Gen Pos',
        15: 'Club',
        16: 'Country'
    }
    
    headers = [header_map[i] for i in sorted(header_map.keys())]
    print(f"Final Headers identified: {headers}")

    # Extract table rows (data)
    data_rows = []
    # Find all <tr> tags, starting from the second <tr> (index 1) as the first is headers
    all_tr_elements = table.find_all('tr')

    # Skip the first <tr> which contains headers
    for tr in all_tr_elements[1:]: # Start from the second row
        row_data = []
        all_tds_in_row = tr.find_all('td')

        # Extract data based on the header_map indices
        for i, td in enumerate(all_tds_in_row):
            if i in header_map:
                # Special handling for 'Flag' column: extract img src
                if header_map[i] == 'Flag':
                    img_tag = td.find('img')
                    if img_tag and 'src' in img_tag.attrs:
                        # Extract just the country code from the flag image URL if possible
                        # e.g., 'https://images.racetec.net/flags/16/ZA.png' -> 'ZA'
                        src = img_tag['src']
                        country_code = src.split('/')[-1].split('.')[0] if '/' in src else ''
                        row_data.append(country_code)
                    else:
                        row_data.append('') # No flag found
                # Special handling for 'Name' column (desktop version) and 'Category'
                # These might contain nested <a> tags whose text we want.
                elif header_map[i] in ['Name', 'Category', 'Gender', 'Club', 'Country']:
                    # Get text from immediate child <a> if available, otherwise direct text
                    link_tag = td.find('a', class_='ltw-name') 
                    if link_tag:
                        row_data.append(link_tag.get_text(strip=True))
                    else: # Fallback for country which might not have a link or direct text
                        row_data.append(td.get_text(strip=True))
                # For simple text columns, get direct text content
                else:
                    # For other columns, get text, stripping whitespace
                    row_data.append(td.get_text(strip=True))
        
        if row_data and len(row_data) == len(headers):  # Ensure row has correct number of columns
            data_rows.append(row_data)
        elif row_data:
                print(f"Warning: Skipping row due to column mismatch: {row_data} (Expected {len(headers)} columns, got {len(row_data)})")


    if data_rows:
        print(f"Successfully extracted {len(data_rows)} data rows.")
    else:
        print("No data rows found in the table body.")
        return None

    # 3. Create Pandas DataFrame
    print("Creating Pandas DataFrame...")
    df = pd.DataFrame(data_rows, columns=headers)
    print("DataFrame created with headers.")
    
    return df

# %%
all_data = pd.DataFrame()  # Initialize an empty DataFrame to collect all data
for page in range(1, 455):  # Adjust the range for more pages if needed
    sleep(3.57)  # Be polite to the server, avoid too many requests in a short time
    url = f"https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo={page}"
    print(url)
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses (4xx or 5xx)

    # 2. Parse the HTML
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the table containing the results
    table = soup.find('table', class_="table table-sm small align-middle ltw-cell-center")

    if not table:
        print(f"No results found on page {page}.")
        continue

    page_data = extract_table_data(table)

    if page_data is not None:
        all_data = pd.concat([all_data, page_data], ignore_index=True)
        print(f"Data from page {page} added. Total rows so far: {len(all_data)}")
# Out:
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=1
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 1 added. Total rows so far: 50
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=2
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 2 added. Total rows so far: 100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=3
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 3 added. Total rows so far: 150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=4
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 4 added. Total rows so far: 200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=5
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 5 added. Total rows so far: 250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=6
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 6 added. Total rows so far: 300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=7
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 7 added. Total rows so far: 350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=8
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 8 added. Total rows so far: 400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=9
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 9 added. Total rows so far: 450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=10
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 10 added. Total rows so far: 500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=11
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 11 added. Total rows so far: 550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=12
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 12 added. Total rows so far: 600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=13
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 13 added. Total rows so far: 650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=14
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 14 added. Total rows so far: 700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=15
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 15 added. Total rows so far: 750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=16
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 16 added. Total rows so far: 800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=17
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 17 added. Total rows so far: 850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=18
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 18 added. Total rows so far: 900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=19
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 19 added. Total rows so far: 950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=20
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 20 added. Total rows so far: 1000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=21
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 21 added. Total rows so far: 1050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=22
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 22 added. Total rows so far: 1100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=23
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 23 added. Total rows so far: 1150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=24
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 24 added. Total rows so far: 1200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=25
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 25 added. Total rows so far: 1250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=26
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 26 added. Total rows so far: 1300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=27
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 27 added. Total rows so far: 1350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=28
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 28 added. Total rows so far: 1400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=29
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 29 added. Total rows so far: 1450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=30
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 30 added. Total rows so far: 1500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=31
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 31 added. Total rows so far: 1550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=32
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 32 added. Total rows so far: 1600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=33
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 33 added. Total rows so far: 1650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=34
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 34 added. Total rows so far: 1700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=35
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 35 added. Total rows so far: 1750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=36
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 36 added. Total rows so far: 1800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=37
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 37 added. Total rows so far: 1850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=38
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 38 added. Total rows so far: 1900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=39
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 39 added. Total rows so far: 1950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=40
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 40 added. Total rows so far: 2000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=41
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 41 added. Total rows so far: 2050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=42
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 42 added. Total rows so far: 2100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=43
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 43 added. Total rows so far: 2150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=44
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 44 added. Total rows so far: 2200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=45
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 45 added. Total rows so far: 2250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=46
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 46 added. Total rows so far: 2300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=47
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 47 added. Total rows so far: 2350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=48
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 48 added. Total rows so far: 2400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=49
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 49 added. Total rows so far: 2450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=50
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 50 added. Total rows so far: 2500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=51
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 51 added. Total rows so far: 2550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=52
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 52 added. Total rows so far: 2600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=53
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 53 added. Total rows so far: 2650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=54
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 54 added. Total rows so far: 2700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=55
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 55 added. Total rows so far: 2750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=56
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 56 added. Total rows so far: 2800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=57
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 57 added. Total rows so far: 2850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=58
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 58 added. Total rows so far: 2900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=59
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 59 added. Total rows so far: 2950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=60
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 60 added. Total rows so far: 3000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=61
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 61 added. Total rows so far: 3050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=62
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 62 added. Total rows so far: 3100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=63
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 63 added. Total rows so far: 3150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=64
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 64 added. Total rows so far: 3200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=65
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 65 added. Total rows so far: 3250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=66
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 66 added. Total rows so far: 3300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=67
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 67 added. Total rows so far: 3350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=68
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 68 added. Total rows so far: 3400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=69
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 69 added. Total rows so far: 3450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=70
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 70 added. Total rows so far: 3500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=71
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 71 added. Total rows so far: 3550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=72
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 72 added. Total rows so far: 3600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=73
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 73 added. Total rows so far: 3650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=74
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 74 added. Total rows so far: 3700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=75
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 75 added. Total rows so far: 3750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=76
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 76 added. Total rows so far: 3800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=77
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 77 added. Total rows so far: 3850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=78
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 78 added. Total rows so far: 3900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=79
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 79 added. Total rows so far: 3950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=80
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 80 added. Total rows so far: 4000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=81
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 81 added. Total rows so far: 4050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=82
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 82 added. Total rows so far: 4100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=83
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 83 added. Total rows so far: 4150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=84
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 84 added. Total rows so far: 4200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=85
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 85 added. Total rows so far: 4250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=86
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 86 added. Total rows so far: 4300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=87
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 87 added. Total rows so far: 4350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=88
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 88 added. Total rows so far: 4400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=89
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 89 added. Total rows so far: 4450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=90
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 90 added. Total rows so far: 4500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=91
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 91 added. Total rows so far: 4550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=92
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 92 added. Total rows so far: 4600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=93
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 93 added. Total rows so far: 4650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=94
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 94 added. Total rows so far: 4700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=95
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 95 added. Total rows so far: 4750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=96
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 96 added. Total rows so far: 4800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=97
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 97 added. Total rows so far: 4850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=98
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 98 added. Total rows so far: 4900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=99
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 99 added. Total rows so far: 4950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=100
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 100 added. Total rows so far: 5000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=101
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 101 added. Total rows so far: 5050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=102
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 102 added. Total rows so far: 5100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=103
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 103 added. Total rows so far: 5150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=104
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 104 added. Total rows so far: 5200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=105
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 105 added. Total rows so far: 5250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=106
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 106 added. Total rows so far: 5300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=107
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 107 added. Total rows so far: 5350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=108
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 108 added. Total rows so far: 5400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=109
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 109 added. Total rows so far: 5450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=110
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 110 added. Total rows so far: 5500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=111
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 111 added. Total rows so far: 5550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=112
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 112 added. Total rows so far: 5600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=113
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 113 added. Total rows so far: 5650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=114
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 114 added. Total rows so far: 5700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=115
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 115 added. Total rows so far: 5750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=116
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 116 added. Total rows so far: 5800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=117
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 117 added. Total rows so far: 5850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=118
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 118 added. Total rows so far: 5900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=119
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 119 added. Total rows so far: 5950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=120
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 120 added. Total rows so far: 6000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=121
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 121 added. Total rows so far: 6050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=122
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 122 added. Total rows so far: 6100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=123
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 123 added. Total rows so far: 6150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=124
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 124 added. Total rows so far: 6200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=125
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 125 added. Total rows so far: 6250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=126
# ...
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 413 added. Total rows so far: 20650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=414
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 414 added. Total rows so far: 20700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=415
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 415 added. Total rows so far: 20750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=416
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 416 added. Total rows so far: 20800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=417
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 417 added. Total rows so far: 20850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=418
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 418 added. Total rows so far: 20900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=419
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 419 added. Total rows so far: 20950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=420
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 420 added. Total rows so far: 21000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=421
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 421 added. Total rows so far: 21050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=422
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 422 added. Total rows so far: 21100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=423
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 423 added. Total rows so far: 21150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=424
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 424 added. Total rows so far: 21200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=425
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 425 added. Total rows so far: 21250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=426
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 426 added. Total rows so far: 21300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=427
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 427 added. Total rows so far: 21350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=428
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 428 added. Total rows so far: 21400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=429
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 429 added. Total rows so far: 21450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=430
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 430 added. Total rows so far: 21500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=431
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 431 added. Total rows so far: 21550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=432
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 432 added. Total rows so far: 21600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=433
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 433 added. Total rows so far: 21650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=434
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 434 added. Total rows so far: 21700
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=435
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 435 added. Total rows so far: 21750
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=436
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 436 added. Total rows so far: 21800
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=437
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 437 added. Total rows so far: 21850
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=438
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 438 added. Total rows so far: 21900
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=439
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 439 added. Total rows so far: 21950
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=440
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 440 added. Total rows so far: 22000
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=441
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 441 added. Total rows so far: 22050
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=442
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 442 added. Total rows so far: 22100
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=443
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 443 added. Total rows so far: 22150
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=444
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 444 added. Total rows so far: 22200
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=445
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 445 added. Total rows so far: 22250
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=446
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 446 added. Total rows so far: 22300
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=447
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 447 added. Total rows so far: 22350
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=448
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 448 added. Total rows so far: 22400
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=449
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 449 added. Total rows so far: 22450
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=450
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 450 added. Total rows so far: 22500
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=451
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 451 added. Total rows so far: 22550
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=452
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 452 added. Total rows so far: 22600
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=453
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 50 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 453 added. Total rows so far: 22650
# https://results.finishtime.co.za/results.aspx?CId=35&RId=30205&EId=1&dt=0&PageNo=454
# Final Headers identified: ['Pos', 'Race No', 'Wave', 'Flag', 'Name', 'Time', 'Net Time', 'Category', 'Cat Pos', 'Gender', 'Gen Pos', 'Club', 'Country']
# Successfully extracted 36 data rows.
# Creating Pandas DataFrame...
# DataFrame created with headers.
# Data from page 454 added. Total rows so far: 22686

# %%
all_data  # Display a sample of the data
# Out:
#       Pos Race No         Wave Flag                 Name      Time  Net Time  \
# 0       1   28951  A - Group 1   ZA          Tete DIJANA  05:25:28  05:25:25
# 1       2   55335  A - Group 1   NL         Piet WIERSMA  05:25:33  05:25:30
# 2       3   31470  A - Group 1   XX       Nikolai VOLKOV  05:29:42  05:29:36
# 3       4   17472  A - Group 1   ZA       Edward MOTHIBI  05:31:41  05:31:38
# 4       5   28773  A - Group 1   ZA       Joseph MANYEDI  05:32:09  05:32:04
# ...    ..     ...          ...  ...                  ...       ...       ...
# 22681       36241  A - Group 1   US          Devon YANKO       DNS       DNS
# 22682       49608  A - Group 1   FR  Pierre-Antoine RUEL       DNS       DNS
# 22683       54048  A - Group 1   ZA      Janie GRUNDLING       DNS       DNS
# 22684       57422  A - Group 1   ZA   Siyabonga MAFULEKA       DNS       DNS
# 22685       59441  A - Group 1   US    Katherine HUGGINS       DNS       DNS
#
#       Category Cat Pos  Gender Gen Pos                       Club  \
# 0       Senior       1    Male       1    NEDBANK RUNNING CLUB GN
# 1       Senior       2    Male       2      NEDBANK INTERNATIONAL
# 2       Senior       3    Male       3  MAXED ELITE INTERNATIONAL
# 3        40-49       1    Male       4    NEDBANK RUNNING CLUB GN
# 4        40-49       2    Male       5            MAXED ELITE KZN
# ...        ...     ...     ...     ...                        ...
# 22681    40-49          Female
# 22682   Senior            Male                            SALOMON
# 22683    40-49          Female                        PHANTANE AC
# 22684   Senior            Male                         SAVAGES AC
# 22685    50-59          Female
#
#                               Country
# 0                        South Africa
# 1                         Netherlands
# 2                                 ANA
# 3                        South Africa
# 4                        South Africa
# ...                               ...
# 22681  United States of America (the)
# 22682                          France
# 22683                    South Africa
# 22684                    South Africa
# 22685  United States of America (the)
#
# [22686 rows x 13 columns]

# %%
# all_data.to_csv('comrades_2025_results.csv', index=False)  # Save the DataFrame to a CSV file
